# %%
from google.colab import drive
import zipfile
import os

# ربط Google Drive
drive.mount('/content/drive')

# مسار ملف ZIP
zip_path = "/content/drive/MyDrive/dataset.zip"
extract_path = "/content/dataset"

# فك الضغط
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ تم فك ضغط البيانات في:", extract_path)
# Out:
# Mounted at /content/drive
# ✅ تم فك ضغط البيانات في: /content/dataset

# %%
from tensorflow.keras.models import load_model

# تحميل النموذج بدون compile لتجنب خطأ الـ optimizer
model = load_model("/content/drive/MyDrive/currency_model_finetuned_final6.h5", compile=False)
print("✅ تم تحميل النموذج بنجاح.")
# Out:
# ✅ تم تحميل النموذج بنجاح.

# %%
from tensorflow.keras.optimizers import Adam

# إعادة إعداد النموذج للتدريب
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
print("🔁 تم إعادة تهيئة النموذج للتدريب.")
# Out:
# 🔁 تم إعادة تهيئة النموذج للتدريب.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# المسارات
TRAIN_DIR = "/content/dataset/dataset/train"
VALIDATION_DIR = "/content/dataset/dataset/valid"  # أو validation حسب اسم المجلد عندك

# تحضير البيانات
def prepare_data(train_dir, val_dir):
    train_gen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        zoom_range=0.2,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True
    )

    val_gen = ImageDataGenerator(rescale=1./255)

    train_data = train_gen.flow_from_directory(train_dir, target_size=(224, 224),
                                               batch_size=32, class_mode='categorical')
    val_data = val_gen.flow_from_directory(val_dir, target_size=(224, 224),
                                           batch_size=32, class_mode='categorical')
    return train_data, val_data

train_data, val_data = prepare_data(TRAIN_DIR, VALIDATION_DIR)
# Out:
# Found 12650 images belonging to 9 classes.
# Found 1708 images belonging to 9 classes.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

callbacks = [
    ModelCheckpoint("/content/drive/MyDrive/currency_model_finetuned_final6.h5", save_best_only=True, verbose=1),
    EarlyStopping(patience=3, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(patience=2, factor=0.2, verbose=1)
]

# %%
# تدريب النموذج
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5,
    callbacks=callbacks
)

print("✅ تم استكمال التدريب 5 مرة إضافية.")

# %%
from tensorflow.keras.optimizers import Adam

# 1️⃣ Fine-Tuning: فك تجميد آخر 10 طبقات
for layer in model.layers[-10:]:
    layer.trainable = True

# إعادة تجميع النموذج بعد تعديل الطبقات القابلة للتدريب
model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])
print("🔧 Fine-Tuning: تم تفعيل آخر 10 طبقات للتدريب.")

# Callbacks جديدة للتدريب الإضافي
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

fine_tune_callbacks = [
    ModelCheckpoint("/content/drive/MyDrive/currency_model_finetuned_final6.h5", save_best_only=True, verbose=1),
    EarlyStopping(patience=3, restore_best_weights=True, verbose=1)
]

# تدريب إضافي 10 مرات
history_finetune = model.fit(train_data, validation_data=val_data, epochs=10, callbacks=fine_tune_callbacks)
print("✅ تم الانتهاء من Fine-Tuning وتخزين النموذج النهائي.")
# Out:
# 🔧 Fine-Tuning: تم تفعيل آخر 10 طبقات للتدريب.
# Epoch 1/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9870 - loss: 0.0465
# Epoch 1: val_loss improved from inf to 1.26983, saving model to /content/drive/MyDrive/currency_model_finetuned_final6.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 1145s 3s/step - accuracy: 0.9870 - loss: 0.0465 - val_accuracy: 0.7898 - val_loss: 1.2698
# Epoch 2/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9877 - loss: 0.0461
# Epoch 2: val_loss improved from 1.26983 to 1.26875, saving model to /content/drive/MyDrive/currency_model_finetuned_final6.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 1089s 3s/step - accuracy: 0.9877 - loss: 0.0461 - val_accuracy: 0.7875 - val_loss: 1.2687
# Epoch 3/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9888 - loss: 0.0352
# Epoch 3: val_loss did not improve from 1.26875
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 1044s 3s/step - accuracy: 0.9888 - loss: 0.0352 - val_accuracy: 0.7840 - val_loss: 1.2864
# Epoch 4/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9875 - loss: 0.0436
# Epoch 4: val_loss did not improve from 1.26875
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 1131s 3s/step - accuracy: 0.9875 - loss: 0.0435 - val_accuracy: 0.7892 - val_loss: 1.2848
# Epoch 5/10
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9889 - loss: 0.0347
# Epoch 5: val_loss did not improve from 1.26875
# 396/396 ━━━━━━━━━━━━━━━━━━━━ 1086s 3s/step - accuracy: 0.9889 - loss: 0.0347 - val_accuracy: 0.7863 - val_loss: 1.2845
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.
# ✅ تم الانتهاء من Fine-Tuning وتخزين النموذج النهائي.

# %%
import tensorflow as tf

# تحويل النموذج إلى TFLite
tflite_model_path = "/content/drive/MyDrive/currency_model_finetuned_final6.tflite"

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# حفظ النموذج TFLite
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)

print("📦 تم تحويل النموذج إلى TFLite وحفظه في:", tflite_model_path)
# Out:
# Saved artifact at '/tmp/tmpn08usptg'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 9), dtype=tf.float32, name=None)
# Captures:
#   135090737642576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090737642192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727258448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090737642960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727257872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090737642768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727258640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727258256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727257296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727258064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727259984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727260944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727261328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727261136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727260752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727260560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727262864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727257104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727263056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727262672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727265168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727265552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727265936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727265744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727262096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727267088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727267472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727267856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727267664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727264016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727269008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727269392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727269776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727269584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727264784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727270160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727271120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727271504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727271312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727270928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727263248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683412752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683413520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727268624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727270736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683414480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683414864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683415248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683415056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683413712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683416400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683416784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683417168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683416976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683412560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683418320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683418704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683419088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683418896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683414096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683420240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683420624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683421008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683420816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683416016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683422160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683422544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683422736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683417936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683424080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683426000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683423696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683421776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683412944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683424464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683424656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683426192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683424848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683428496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683425808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683427536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727241104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727240144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727240912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727239952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727242640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727243024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727243408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727243216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727240336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727244560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727244944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727245328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727245136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727241488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727246480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727246864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727247248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727247056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727242256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727248400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727248784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727249168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727248976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727244176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727250320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727250704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727251088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727250896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727246096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727252240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727252624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727253008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727252816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727248016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727254160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727254544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727254928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727254736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727249936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727251856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683838928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683839504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727253776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090727253392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683840464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683840848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683841232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683841040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683839696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683842384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683842768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683843152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683842960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683838736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683844304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683844688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683845072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683844880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683840080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683846224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683846608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683846992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683846800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683842000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683848144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683848528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683848912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683848720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683843920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683850064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683850448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683850832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683850640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683845840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683851984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683852368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683852752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683852560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683847760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683853904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683853520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683853136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683854480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683849680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683851600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683970960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683970000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683970768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683969808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683972496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683972880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683973264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683973072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683970192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683974416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683974800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683975184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683974992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683971344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683976336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683976720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683977104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683976912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683972112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683978256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683978640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683979024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683978832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683974032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683980176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683980560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683980944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683980752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683975952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683982096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683982480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683982864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683982672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683977872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683984016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683984400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683984784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683984592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683979792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683981712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684199376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684199952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683983632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090683983248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684200912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684201296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684201680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684201488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684200144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684202832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684203216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684203600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684203408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684199184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684204752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684205136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684205520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684205328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684200528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684206672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684207056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684207440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684207248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684202448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684208592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684208976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684209360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684209168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684204368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684210512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684210896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684211280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684211088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684206288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684212432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684214160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684210128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684213008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684208208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684212816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684213584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684198992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684214544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684212048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684213200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684151184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684150224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684150992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684150032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684152720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684153296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684152336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684154064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684153488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135090684154832: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 📦 تم تحويل النموذج إلى TFLite وحفظه في: /content/drive/MyDrive/currency_model_finetuned_final6.tflite
